# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
result = pd.read_csv('predict.csv')
real_price = result['label']
predicted_price = result['predict']
low_freq = result['low_freq']
# Out:
# (11, 4)

# %%
plt.plot(real_price, color = 'black', label = 'Real Credit Spread')
plt.plot(predicted_price, color = 'green', label = 'Predicted Credit Spread')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.plot(real_price[100:300], color = 'black', label = 'Real Credit Spread')
plt.plot(low_freq[100:300], color = 'green', label = 'Predicted Credit Spread')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
