# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
result = pd.read_csv('predict.csv')
real_price = result['label']
predicted_price = result['predict']
low_freq = result['low_freq']

# %%
result.loc[0:1]
# Out:
#    high_freq  low_freq   predict  label
# 0  -0.003809  0.752297  0.748489   0.81
# 1   0.041826  0.772265  0.814091   0.82

# %%
plt.plot(real_price, color = 'black', label = 'Real Credit Spread')
plt.plot(predicted_price, color = 'green', label = 'Predicted Credit Spread')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.plot(real_price[:100], color = 'black', label = 'Real Credit Spread')
plt.plot(low_freq[:100], color = 'green', label = 'Predicted Credit Spread')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
